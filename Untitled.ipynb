# %%
from users.models import FacebookFile

# %%
all_user_file_objects = FacebookFile.objects.filter(user=25)

# %%
all_user_file_objects[0].path_to_facebook_data
# Out:
# '/data/user_facebook_data/2510_12_2019_12_57_38335714262433294694355351431373007345367/index.html'

# %%
import pandas as pd

# %%
df = pd.read_json('friends.json')

# %%
import json

# %%
with open('friends.json') as json_file:
    file = json.load(json_file)

# %%
file['friends'][0]
# Out:
# {'name': 'Muhammad Abid Khan', 'timestamp': 1575996626}

# %%
with open('/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2511_12_2019_05_33_59234605517672392410956306306087603262748/location/location_history.json') as json_file:
    file = json.load(json_file)

# %%
file['location_history']
# Out:
# [{'name': 'Karachi',
#   'coordinate': {'latitude': 24.8424918, 'longitude': 67.0799635},
#   'creation_timestamp': 1575952406},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.84968, 'longitude': 66.99479},
#   'creation_timestamp': 1575859459},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.84511, 'longitude': 67.03151},
#   'creation_timestamp': 1575522544},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.85442, 'longitude': 66.98876},
#   'creation_timestamp': 1575519680},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.84864, 'longitude': 66.99573},
#   'creation_timestamp': 1575472057},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.842361450195, 'longitude': 67.079978942871},
#   'creation_timestamp': 1575133490}]

# %%
with open('/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/25_khan/friends/friends.json') as json_file:
    file = json.load(json_file)

# %%
len(file['reactions'])
# Out:
# 72

# %%
file['friends'][:10]
# Out:
# [{'name': 'Qudrat Khan', 'timestamp': 1576077214},
#  {'name': 'Atiqullah Atiqullah', 'timestamp': 1576077213},
#  {'name': 'Muhammad Abid Khan', 'timestamp': 1575996626},
#  {'name': 'Atta Khan Atta Khan', 'timestamp': 1575914226},
#  {'name': 'Nadeem Iqbal', 'timestamp': 1575658970},
#  {'name': 'Ghulam Nabi Afridi', 'timestamp': 1575623269},
#  {'name': 'Faraz MK Faraz MK', 'timestamp': 1575534947},
#  {'name': 'Fawad Saeed', 'timestamp': 1575534946},
#  {'name': 'Muhammad Areeb', 'timestamp': 1575479900},
#  {'name': 'Ashraf Wafa', 'timestamp': 1575393736}]

# %%
with open('/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2511_12_2019_05_33_59234605517672392410956306306087603262748/comments/comments.json') as json_file:
    file = json.load(json_file)

# %%
len(file['comments'])
# Out:
# 44

# %%
with open('/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2511_12_2019_05_33_59234605517672392410956306306087603262748/stories/story_reactions.json') as json_file:
    file = json.load(json_file)

# %%
len(file['stories_feedback'])
# Out:
# 37

# %%
import gmaps
gmaps.configure(api_key='AIzaSyAgs7FjH1vOrEH11N7v2UcoMbFkvDwbLmk')

# %%
new_york_coordinates = (24.8424918, 67.0799635)
gmaps.figure(center=new_york_coordinates, zoom_level=12)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
file['location_history']
# Out:
# [{'name': 'Karachi',
#   'coordinate': {'latitude': 24.8424918, 'longitude': 67.0799635},
#   'creation_timestamp': 1575952406},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.84968, 'longitude': 66.99479},
#   'creation_timestamp': 1575859459},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.84511, 'longitude': 67.03151},
#   'creation_timestamp': 1575522544},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.85442, 'longitude': 66.98876},
#   'creation_timestamp': 1575519680},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.84864, 'longitude': 66.99573},
#   'creation_timestamp': 1575472057},
#  {'name': 'Karachi',
#   'coordinate': {'latitude': 24.842361450195, 'longitude': 67.079978942871},
#   'creation_timestamp': 1575133490}]

# %%
# marker_locations = [
# (-34.0, -59.166672),
# (-32.23333, -64.433327),
# (40.166672, 44.133331),
# (51.216671, 5.0833302),
# (51.333328, 4.25)
# ]
marker_location = []

# %%
for i in file['location_history']:
    marker_location.append((i['coordinate']['latitude'],i['coordinate']['longitude']))

# %%
marker_location
# Out:
# [(24.8424918, 67.0799635),
#  (24.84968, 66.99479),
#  (24.84511, 67.03151),
#  (24.85442, 66.98876),
#  (24.84864, 66.99573),
#  (24.842361450195, 67.079978942871)]

# %%
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_location)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
type(fig)
# Out:
# gmaps.figure.Figure

# %%
import ipywidgets

# %%
outer_box = ipywidgets.HBox([fig])

# %%
outer_box

# %%
cd ..
# Out:
# /home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2511_12_2019_05_33_59234605517672392410956306306087603262748

# %%
ls
# Out:
# about_you/                  messages/
# ads/                        other_activity/
# apps_and_websites/          pages/
# comments/                   payment_history/
# events/                     photos_and_videos/
# facebook-muneerkhan555.zip  posts/
# following_and_followers/    profile_information/
# friends/                    saved_items_and_collections/
# groups/                     search_history/
# index.html                  security_and_login_information/
# likes_and_reactions/        stories/
# location/                   your_places/
# marketplace/

# %%
import os.path
import time
while True:
    
    if os.path.exists('Anroid') in 'android':
        print ("File exist")
        break
    else:
        print("not exists")
        time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-293-0997311cb44e> in <module>
#       3 while True:
#       4
# ----> 5     if os.path.exists('Anroid') in 'android':
#       6         print ("File exist")
#       7         break
#
# TypeError: 'in <string>' requires string as left operand, not bool

# %%
cd /home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2511_12_2019_05_33_59234605517672392410956306306087603262748
# Out:
# /home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2511_12_2019_05_33_59234605517672392410956306306087603262748

# %%
cd ..
# Out:
# /home/muneer/Documents/FL/ritaapphai/data/user_facebook_data

# %%
ls
# Out:
# 1925_09_2019_19_49_12/
# 1925_09_2019_19_54_43/
# 1925_09_2019_19_58_22/
# 1926_09_2019_12_15_20102403722891108693863529878605865411494/
# 1926_09_2019_12_15_2010751366394154851651535686243697373536/
# 1926_09_2019_12_15_20113611850252120442431061922622986983678/
# 1926_09_2019_12_15_20115321834329885226913494377315030242107/
# 1926_09_2019_12_15_20119132649669571019270500275443573804774/
# 1926_09_2019_12_15_20128408082108151223749176249133317328807/
# 1926_09_2019_12_15_2013266784104000368863368172087640449504/
# 1926_09_2019_12_15_20147833158303493496337830531821597612114/
# 1926_09_2019_12_15_2015995474227990176030718464612225004154/
# 1926_09_2019_12_15_20162569829812343847304837222725005437681/
# 1926_09_2019_12_15_20167641962378931380029389529901707746948/
# 1926_09_2019_12_15_20179522080478662291650001021095617545009/
# 1926_09_2019_12_15_20183155120385271306314358105926494887156/
# 1926_09_2019_12_15_20190759170791448847015176257210315817655/
# ...

# %%
cd 2512_12_2019_11_50_4658081506434191490519986908079593445375/
# Out:
# /home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2512_12_2019_11_50_4658081506434191490519986908079593445375

# %%
import matplotlib.pyplot as plt

# %%
# x-coordinates of left sides of bars  
left = [1, 2, 3, 4, 5] 
  
# heights of bars 
height = [10, 24, 36, 40, 5] 
  
# labels for bars 
tick_label = ['one', 'two', 'three', 'four', 'five'] 
  
# plotting a bar chart 
plt.bar(left, height, tick_label = tick_label, 
        width = 0.8, color = ['red', 'green']) 
  
# naming the x-axis 
plt.xlabel('x - axis') 
# naming the y-axis 
plt.ylabel('y - axis') 
# plot title 
plt.title('My bar chart!') 
  
# function to show the plot 
plt.show()

# %%
ls
# Out:
# about_you/                  messages/
# ads/                        other_activity/
# apps_and_websites/          pages/
# comments/                   payment_history/
# events/                     photos_and_videos/
# facebook-muneerkhan555.zip  posts/
# following_and_followers/    profile_information/
# friends/                    saved_items_and_collections/
# groups/                     search_history/
# likes_and_reactions/        security_and_login_information/
# location/                   stories/
# marketplace/                your_places/

# %%
import json

# %%
with open('/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2512_12_2019_11_50_4658081506434191490519986908079593445375/comments/comments.json') as json_file:
    comments = json.load(json_file)

# %%
len(comments['comments'])
# Out:
# 114

# %%
comments['comments']
# Out:
# [{'timestamp': 1576080413,
#   'data': [{'comment': {'timestamp': 1576080414,
#      'comment': 'Syed Fahad  Shamim Usman Paracha',
#      'author': 'Muneer Khan'}}],
#   'title': "Muneer Khan commented on Ahmed Rauf Essa's video."},
#  {'timestamp': 1576080232,
#   'data': [{'comment': {'timestamp': 1576080232,
#      'comment': 'Syed Fahad  Shamim Usman Parachausman Danish Khalid',
#      'author': 'Muneer Khan'}}],
#   'title': "Muneer Khan commented on Rajnikant V/s CID Jokes Videos's video."},
#  {'timestamp': 1575945533,
#   'data': [{'comment': {'timestamp': 1575945533,
#      'comment': 'Shoaib Khan Achakzai Aman Ullah',
#      'author': 'Muneer Khan'}}],
#   'title': "Muneer Khan commented on Aslam Rind Music Collection's video."},
#  {'timestamp': 1575945388,
#   'data': [{'comment': {'timestamp': 1575945388,
#      'comment': 'You should try simple from login.views import home',
#      'author': 'Muneer Khan',
#      'group': 'Django Python Web Framework'}}],
# ...

# %%
import os

path, dirs, files = next(os.walk("/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/2512_12_2019_11_50_4658081506434191490519986908079593445375/messages/inbox"))
file_count = len(dirs)

# %%
dirs
# Out:
# ['MohabbatUllahAgha_ne2EiL5IBg',
#  'muzamilkhan_qlvbc0afja',
#  'AlishahAchakzai_0k_ZnYx3NQ',
#  'NoorShah_roXVGJ8bpw',
#  'khurramabbassarani_fbrytwqi6a',
#  'attalkhanshaistaachakzai_-hbageeuzq',
#  'nsybsrfraz_hskz-lzbsa',
#  'ShahnawazIrfan_IhpPKqdccg',
#  'ZahirShah_JaUDuBP1Lg',
#  'AbdulWassay_pNTAv0NcLA',
#  'bachakhanbachakhan_xgno48effw',
#  'sharafkhanachakzai_6ipym4mjow',
#  'nsybsrfraz_hskZ-LzbSA',
#  'rafiqkhan_ao8otilqpg',
#  'hikmatfaryadi_ag35naswmw',
#  'kashanasif_ifmptfag4w',
#  'sahariyarsadekinshovon_nn69x-lu3q',
#  'khankhan_p-h94h1_ra',
#  'muhammadatif_kvrx1wmwda',
#  'HashimiSayedzahershah_wOF38tKGWw',
#  'shahnader_mq9_m8zupa',
#  'NajeebKhan_XvZnl32WmQ',
#  'shoaibkhanachakzai_3bltijugsw',
#  'AshrafKhan_XvBBXdHIDQ',
#  'hashimisayedzahershah_wof38tkgww',
#  'naseebullahshaki_ccdkriwfyg',
#  'nomanzamir_ocdrpzdxjw',
#  'mustafaabbas_afatxffkcw',
#  'ranausama_i5ntmbto7q',
#  'ShahNader_mQ9_m8ZupA',
#  'asiffaisalshoaibkhanand10others_izr1tjc3zg',
# ...

# %%
def folder_size(path):
    total = 0
    for entry in os.scandir(path):
        if entry.is_file():
            total += entry.stat().st_size
        elif entry.is_dir():
            total += folder_size(entry.path)
    return total

# %%
folder_size('/home/muneer/Documents/FL/ritaapphai/data/user_facebook_data/25_khan')
# Out:
# 1922474

# %%
import requests

# %%
url = 'https://www.facebook.com/'

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html lang="ur" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script>window._cstart=+new Date();</script><script>function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"ajaxpipe_token":"AXg6RIRKsC-qEMDI","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"isHeartbeatEnabled":true,"isArtilleryOn":false},"shouldLogCounters":true,"timeslice_categories":{"react_render":true,"reflow":true},"sample_continuation_stacktraces":true,"dom_mutation_flag":true,"stack_trace_limit":30,"deferred_stack_trace_rate":1000,"timesliceBufferSize":5000,"show_invariant_decoder":false,"compat_if
# ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no_js" id="facebook" lang="ur">
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no_js" id="facebook" lang="ur">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <script>
#    window._cstart=+new Date();
#   </script>
#   <script>
# ...
